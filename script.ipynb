# %%
import pandas as pd
import math

# %%
# 22 covid isolation
# 30 anxious
# 40 feeling isolated
# 41 trust
# 81 extravert
# 82 reserved
# 109 distress
# 110 staying inside
df = pd.read_csv('./data/COVIDiSTRESS.csv', usecols=[22, 30,40, 41, 81, 82, 109, 110])
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                                      Dem_islolation  \
# 0       What best describes your current situation?
# 1                              {"ImportId":"QID17"}
# 2                                               NaN
# 3                Life carries on with minor changes
# 4                                               NaN
# ...                                             ...
# 139223                                     Isolated
# 139224           Life carries on with minor changes
# 139225                                          NaN
# 139226                                          NaN
# 139227                                          NaN
#
#                                        Scale_PSS10_UCLA_3  \
# 0       In the last week, how often have you... - felt...
# 1                                  {"ImportId":"QID29_3"}
# 2                                                     NaN
# 3                                            Fairly often
# ...

# %%
df = pd.read_csv('./data/COVIDiSTRESS.csv', usecols=[22, 30,40, 41, 81, 82, 109, 110], skiprows=[1,2])

# %%
df
# Out:
#                             Dem_islolation Scale_PSS10_UCLA_3  \
# 0                                      NaN                NaN
# 1       Life carries on with minor changes       Fairly often
# 2                                      NaN                NaN
# 3       Life carries on with minor changes          Sometimes
# 4                                      NaN                NaN
# ...                                    ...                ...
# 139221                            Isolated       Fairly often
# 139222  Life carries on with minor changes       Almost never
# 139223                                 NaN                NaN
# 139224                                 NaN                NaN
# 139225                                 NaN                NaN
#
#        Scale_PSS10_UCLA_13  OECD_people_1           BFF_15_5        BFF_15_6  \
# 0                      NaN            NaN                NaN             NaN
# ...

# %%
df.shape
# Out:
# (139226, 8)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (79878, 8)

# %%
df
# Out:
#                             Dem_islolation Scale_PSS10_UCLA_3  \
# 1       Life carries on with minor changes       Fairly often
# 3       Life carries on with minor changes          Sometimes
# 5                                 Isolated       Fairly often
# 6                                 Isolated          Sometimes
# 8       Life carries on with minor changes       Almost never
# ...                                    ...                ...
# 139218  Life carries on with minor changes       Almost never
# 139219  Life carries on with minor changes          Sometimes
# 139220                            Isolated          Sometimes
# 139221                            Isolated       Fairly often
# 139222  Life carries on with minor changes       Almost never
#
#        Scale_PSS10_UCLA_13  OECD_people_1           BFF_15_5  \
# 1               Very often            5.0              Agree
# 3                    Never            7.0  Slightly disagree
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                             Dem_islolation Scale_PSS10_UCLA_3  \
# 1       Life carries on with minor changes       Fairly often
# 3       Life carries on with minor changes          Sometimes
# 5                                 Isolated       Fairly often
# 6                                 Isolated          Sometimes
# 8       Life carries on with minor changes       Almost never
# ...                                    ...                ...
# 139218  Life carries on with minor changes       Almost never
# 139219  Life carries on with minor changes          Sometimes
# 139220                            Isolated          Sometimes
# 139221                            Isolated       Fairly often
# 139222  Life carries on with minor changes       Almost never
#
#        Scale_PSS10_UCLA_13  OECD_people_1           BFF_15_5  \
# 1               Very often            5.0              Agree
# 3                    Never            7.0  Slightly disagree
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79878 entries, 1 to 139222
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Dem_islolation       79878 non-null  object
#  1   Scale_PSS10_UCLA_3   79878 non-null  object
#  2   Scale_PSS10_UCLA_13  79878 non-null  object
#  3   OECD_people_1        79878 non-null  float64
#  4   BFF_15_5             79878 non-null  object
#  5   BFF_15_6             79878 non-null  object
#  6   Expl_Distress_18     79878 non-null  object
#  7   Expl_Distress_19     79878 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 5.5+ MB

# %%
df.describe()
# Out:
#        OECD_people_1
# count   79878.000000
# mean        5.573900
# std         2.073983
# min         0.000000
# 25%         4.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000

# %%
df.to_csv('./data/dataset2-output.csv', index=False)
