# %%
import pandas as pd
import math

# %%
df = pd.read_csv('./data/COVIDiSTRESS.csv', usecols=[22, 24, 40, 41, 81, 82, 109])
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (24,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                                      Dem_islolation  \
# 0       What best describes your current situation?
# 1                              {"ImportId":"QID17"}
# 2                                               NaN
# 3                Life carries on with minor changes
# 4                                               NaN
# ...                                             ...
# 139223                                     Isolated
# 139224           Life carries on with minor changes
# 139225                                          NaN
# 139226                                          NaN
# 139227                                          NaN
#
#                                        Dem_isolation_kids  \
# 0       If in relative isolation, how many children un...
# 1                                    {"ImportId":"QID26"}
# 2                                                     NaN
# 3                                                       1
# ...

# %%
# 22 covid isolation
# 24 dependents
# 40 feeling isolated
# 41 trust
# 81 extravert
# 82 reserved
# 109 distress
df = pd.read_csv('./data/COVIDiSTRESS.csv', usecols=[22, 24, 40, 41, 81, 82, 109], skiprows=[1,2])

# %%
df
# Out:
#                             Dem_islolation  Dem_isolation_kids  \
# 0                                      NaN                 NaN
# 1       Life carries on with minor changes                 1.0
# 2                                      NaN                 NaN
# 3       Life carries on with minor changes                 NaN
# 4                                      NaN                 NaN
# ...                                    ...                 ...
# 139221                            Isolated                 6.0
# 139222  Life carries on with minor changes                 0.0
# 139223                                 NaN                 NaN
# 139224                                 NaN                 NaN
# 139225                                 NaN                 NaN
#
#        Scale_PSS10_UCLA_13  OECD_people_1           BFF_15_5        BFF_15_6  \
# 0                      NaN            NaN                NaN             NaN
# ...

# %%
df.shape
# Out:
# (139226, 7)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (66745, 7)

# %%
df
# Out:
#                             Dem_islolation  Dem_isolation_kids  \
# 1       Life carries on with minor changes                 1.0
# 5                                 Isolated                 0.0
# 6                                 Isolated                 0.0
# 8       Life carries on with minor changes                 0.0
# 11      Life carries on with minor changes                 0.0
# ...                                    ...                 ...
# 139216                            Isolated                 0.0
# 139219  Life carries on with minor changes                 1.0
# 139220                            Isolated                 0.0
# 139221                            Isolated                 6.0
# 139222  Life carries on with minor changes                 0.0
#
#        Scale_PSS10_UCLA_13  OECD_people_1           BFF_15_5  \
# 1               Very often            5.0              Agree
# 5             Fairly often            7.0     Slightly agree
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                             Dem_islolation  Dem_isolation_kids  \
# 1       Life carries on with minor changes                 1.0
# 5                                 Isolated                 0.0
# 6                                 Isolated                 0.0
# 8       Life carries on with minor changes                 0.0
# 11      Life carries on with minor changes                 0.0
# ...                                    ...                 ...
# 139216                            Isolated                 0.0
# 139219  Life carries on with minor changes                 1.0
# 139220                            Isolated                 0.0
# 139221                            Isolated                 6.0
# 139222  Life carries on with minor changes                 0.0
#
#        Scale_PSS10_UCLA_13  OECD_people_1           BFF_15_5  \
# 1               Very often            5.0              Agree
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66745 entries, 1 to 139222
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Dem_islolation       66745 non-null  object
#  1   Dem_isolation_kids   66745 non-null  float64
#  2   Scale_PSS10_UCLA_13  66745 non-null  object
#  3   OECD_people_1        66745 non-null  float64
#  4   BFF_15_5             66745 non-null  object
#  5   BFF_15_6             66745 non-null  object
#  6   Expl_Distress_18     66745 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#        Dem_isolation_kids  OECD_people_1
# count        66745.000000   66745.000000
# mean             0.457457       5.563832
# std              1.335217       2.083063
# min              0.000000       0.000000
# 25%              0.000000       4.000000
# 50%              0.000000       6.000000
# 75%              1.000000       7.000000
# max            110.000000      10.000000

# %%
dep_col = df.iloc[:,1]

# %%
std = dep_col.std()
std
# Out:
# 1.3352167261293788

# %%
mean = dep_col.mean()
mean
# Out:
# 0.4574574874522436

# %%
max_dep_allowed = 4 * std + mean
max_dep_allowed
# Out:
# 5.798324391969759

# %%
max_dep_allowed = math.ceil(max_dep_allowed)
max_dep_allowed
# Out:
# 6

# %%
filtered_df = df[df['Dem_isolation_kids'] <= max_dep_allowed]

# %%
filtered_df.describe()
# Out:
#        Dem_isolation_kids  OECD_people_1
# count        66682.000000   66682.000000
# mean             0.438559       5.564215
# std              0.818082       2.082698
# min              0.000000       0.000000
# 25%              0.000000       4.000000
# 50%              0.000000       6.000000
# 75%              1.000000       7.000000
# max              6.000000      10.000000

# %%
df.to_csv('./data/dataset2-output.csv', index=False)
