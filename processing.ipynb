# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# 22 covid isolation
# 24 dependents
# 40 feeling isolated
# 41 trust
# 81 extravert
# 82 reserved
# 109 distress
df = pd.read_csv('./data/COVIDiSTRESS.csv', usecols=[22, 24, 40, 41, 81, 82, 109])
# Out:
# /var/folders/20/5s6xdt6n32998hy8h6qcsg_00000gn/T/ipykernel_46669/3164012805.py:8: DtypeWarning: Columns (24,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./data/COVIDiSTRESS.csv', usecols=[22, 24, 40, 41, 81, 82, 109])

# %%
df
# Out:
#                                      Dem_islolation  \
# 0       What best describes your current situation?
# 1                              {"ImportId":"QID17"}
# 2                                               NaN
# 3                Life carries on with minor changes
# 4                                               NaN
# ...                                             ...
# 139223                                     Isolated
# 139224           Life carries on with minor changes
# 139225                                          NaN
# 139226                                          NaN
# 139227                                          NaN
#
#                                        Dem_isolation_kids  \
# 0       If in relative isolation, how many children un...
# 1                                    {"ImportId":"QID26"}
# 2                                                     NaN
# 3                                                       1
# ...
